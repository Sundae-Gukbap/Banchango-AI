# %%
with open("sorted_ingredients_count.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()
    
categories = {
    "채소": ["마늘", "양파", "대파", "청양고추", "당근", "무", "오이", "생강", "쪽파", "부추", 
           "애호박", "깻잎", "풋고추", "새송이버섯", "양배추", "표고버섯", "양송이버섯", "팽이버섯", 
           "고구마", "느타리버섯", "시금치", "가지", "호박", "브로콜리", "상추", "쑥갓", "달래", 
           "치커리", "양상추", "시래기", "얼갈이배추", "배추", "미나리", "숙주", "배추", "파프리카", 
           "케일", "아스파라거스", "비트", "콩나물", "깍두기", "고사리", "토란대", "엔다이브", 
           "청경채", "연근", "우엉", "열무", "파슬리", "고춧잎", "근대", "해바라기잎", "버섯", "쪽파", 
           "샐러리", "청경채", "바질", "허브", "바질잎", "루꼴라", "로메인상추", "파", '홍고추',
           '감자', '피망', '고추', '꽈리고추', '단호박', '어린잎채소', '알배추', '마늘쫑', '실파',
           '올리브', '건고추', '냉이', '채소', '봄동', '옥수수', '무순', '적양파', '인삼', '참나물',
           '샐러드채소', '파뿌리', '쑥', '도라지', '목이버섯', '취나물', '두릅', '세발나물', '은행',
           '베트남고추', '더덕', '죽순', '돌나물', '노각', '무청', '쌈채소', '고구마줄기', '수삼', 
           '로메인', '적채', '실고추', '할라피뇨', '대파뿌리', '아욱', '계피', '황기', '우거지', 
           '만가닥버섯', '깻잎순', '콜라비', '주키니호박', '호박잎', '마', '연두순', '맛타리버섯', 
           '송이버섯', '방풍나물', '풋마늘', '비름나물', '딜', '고구마순', '방아잎', '갓', '로메인상추',
           '유채나물', '머위', '쥐똥고추', '샬롯', '머위대', '섬초', '콜리플라워', '명이나물', '토란',
           '고기느타리버섯', '당귀', '방울양배추', '고춧씨', '총각무', '나물', '무생채', '호박고지',
           '엄나무', '곰취', '백만송이버섯', '명엽채', '엄나무순', '곤드레나물', '공심채', '참타리버섯',
           '홍갓', '백합', '머쉬마루 버섯', '미니양배추', 
           ],
    "곡물": ['밀가루', '쌀', '전분가루', '밀가루 박력분', '찹쌀', '밀가루 강력분', '오트밀', '박력쌀가루',
           '현미', '밀가루풀', '강력쌀가루', '귀리', '수수', 
           ],
    "절임 및 장아찌": ['김치', '새우젓', '묵은김치', '명란', '열무김치', '무말랭이', '깍두기', '갓김치',
                      '파김치', '총각김치', '백김치', '볶음김치', '동치미 무', '갈치속젓', '고추장아찌',],
    "과일": ["사과", "바나나", "딸기", "방울토마토", "배", "토마토", "포도", "체리", "복숭아", 
           "자몽", "귤", "블루베리", "키위", "메론", "망고", "무화과", "오렌지", "수박", "파인애플", 
           "아보카도", "자두", "레몬", "라임", "바나나칩", "곶감", '매실', '크랜베리', '참외',
           '단감', '과일', '청포도', '천도복숭아', '홍시', '냉동딸기', '산딸기', '건과일', '석류',
           '청귤', '한라봉', 
           ],
    "육류": ["소고기", "돼지고기", "닭고기", "계란", "소시지", "베이컨", "햄", "순대", "족발", "차돌박이",
           "닭발", "닭똥집", "닭가슴살", "닭다리살", "돼지등갈비", "돼지갈비", "돼지목살", "돼지등뼈", 
           "갈비", "사골", "닭봉", "곱창", "우삼겹", "소고기 불고기용", "소고기 다짐육", 
           "돼지고기 다짐육", "돼지고기 삼겹살", "돼지앞다리살", "돼지목살", "소고기 국거리", "닭발", 
           "돼지등뼈", '스팸', '닭', '소세지', '비엔나소세지', '돼지고기 앞다리살', '대패삼겹살',
           '메추리알', '훈제오리', '돼지고기 목살', '후랑크소세지', '닭안심', '소고기 국거리', '소고기 양지',
           '돼지고기 안심', '돼지고기 등심', '돈까스', '목살', '소갈비', '김밥용 햄', '치킨', '통삼겹살',
           '소고기 등심', '불고기', 'LA갈비', '떡갈비', '소고기 사태', '오리고기', '고기', '소고기 안심',
           '소고기 부채살', '다짐육', '등심', '다진고기', '항정살', '치킨너겟', '돼지 앞다리살', '돼지고기 뒷다리살',
           '돼지고기 불고기용', '미트볼', '치킨텐더', 
           
           ],
    "해산물 및 해조류": ["새우", "오징어", "고등어", "명태", "조기", "갈치", "꽁치", "대구", "연어", "바지락", 
            "조개", "굴", "홍합", "해삼", "멸치", "오징어젓", "쭈꾸미", "전복", "바닷가재",
            "문어", "바지락", "게", "어묵", "명란젓", "건새우", "진미채", "황태", "황태채", "멍게", 
            "청어", "가자미", "주꾸미", "조갯살", "해물믹스", "해파리", "말린멸치", "낙지", "대구살", 
            "민어", '다시마', '맛살', '미역', '김', '참치캔', '김밥김', '참치', '골뱅이', '꽃게', '꼬막',
            '날치알', '북어채', '코다리', '매생이', '파래', '동태', '대하', '톳', '오징어채', '삼치',
            '가리비', '우렁이', '모시조개', '장어', '갑오징어', '황태포', '관자', '미더덕', '동태포',
            '황태머리', '쥐포', '반건조오징어', '물미역', '오징어실채', '굴비', '지리멸치', '감태', 
            '소라', '크레미', '아귀', '우럭', '오만둥이', '병어', '꼬시래기', '전어', '과메기', '밴댕이',
            '생선', '도루묵', 
            ],
    "유제품": ["우유", "버터", "치즈", "모짜렐라치즈", "생크림", "크림치즈", "요거트", "연유", "마가린", 
            "슬라이스치즈", "파마산치즈", "치즈가루", "요거트", "플레인요구르트", "리코타치즈", "체다치즈", 
            "휘핑크림", "코티지치즈", "사워크림", "치즈스프레드", "고다치즈", "크림치즈", '브리치즈',
            '피자치즈', '스트링치즈', '그라나파다노치즈',  '마스카포네치즈', '슈레드치즈', '고르곤졸라치즈',
            ],
    "콩류 및 견과류": ["땅콩", "호두", "아몬드", "참깨", "깨", "아몬드슬라이스", "피칸", "잣", "들깨",
                     "해바라기씨", "검은깨", "대추씨", "해바라기씨유", "마카다미아", '두부',
                     "치아씨드", "파인너트", "해바라기씨", "플렉스시드", "아몬드가루", "참깨가루",
                     '대추', '견과류', '순두부', '밤', '팥', '건포도', '검정깨', '완두콩', '호박씨', 
                     '연두부', '흑임자', '병아리콩', '검은콩', '캐슈넛', '콩비지', '피스타치오', '그린빈',
                     '녹두', '서리태', '땅콩분태', '콩', '땅콩가루', '강낭콩', '통아몬드', '비지', '생땅콩',
                     '렌틸콩', '아마씨', '햄프씨드', '백태', '메주콩', '통들깨', 
                     
                     ],
    "조미료 및 향신료": ["소금", "설탕", "간장", "후추", "고춧가루", "식초", "고추장", "된장", 
                  "쌈장", "춘장", "굴소스", "참기름", "들기름", "깨소금", "맛술", 
                  "올리고당", "액젓", "레몬즙", "허브", "허브솔트", "바질", "월계수잎", 
                  "파슬리가루", "페페론치노", "파프리카가루", "케이퍼", "향신료", "갈릭파우더", 
                  "바질가루", "로즈마리", "고수", "시나몬", "머스타드", "겨자", "파마산치즈",
                  "꿀", "매실액", "다시다", "바닐라익스트랙", "바닐라빈", "육수", '마요네즈',
                  "멸치액젓", "생강가루", "고추기름", "감초", "생강즙", "겨자", '국간장' 
                  "생강", "양파가루", "청양고춧가루", "고추냉이", "식용유", "올리브유",
                  '후춧가루', '물엿', '매실청', '청주', '케찹', '기름', '베이킹파우더', '미림',
                  '맛간장', '들깨가루', '카레가루', '파마산치즈가루', '포도씨유', '토마토소스',
                  '슈가파우더', '계피가루', '맛소금', '생강술', '멸치다시마', '카놀라유',
                  '발사믹식초', '조청', '흑설탕', '치킨스톡', '생강청', '초고추장', '쯔유',
                  '요리당', '두반장', '와사비', '화이트와인', '칠리소스', '돈까스소스', '메이플시럽',
                  '가다랑어포', '배즙', '우스터소스', '유자청', '스테이크소스', '콩기름', '원당',
                  '마늘가루', '코인육수', '데리야끼소스', '멸치가루', '청국장', '핫소스', '구운소금',
                  '천연조미료', '연두', '아가베시럽', '미원', '현미유', '미향', '바닐라오일', '피쉬소스',
                  '레드와인', '해바라기유', '정종', '스파게티소스', '바질페스토', '조미료', '홍초', '짜장가루',
                  '코코넛오일', '피클링스파이스', '스리라차소스', '양념장', '럼주', '강황가루',
                  '타임', '사과즙', '뉴슈가', '오레가노', '시럽', '아보카도오일', '레몬청', '생와사비', 
                  '노두유', '후리가케', '스테비아', '애플민트', '팔각', '식물성 기름', '피자소스',
                  '미스된장', '라임즙', '엿기름', '불닭소스', '육수팩', '정향', '민트', '혼다시', 
                  '양파청', '쌀엿', '볶은소금', '바베큐소스', '와인', '매실즙', '레몬제스트', '크림소스',
                  '멸치다시다', '소스', '분당', '다싯물', '참소스', '오미자청', '마라소스', '타르타르소스',
                  '트러플오일', '산초가루', '오리엔탈드레싱', '사과청', '함초소금', 
                  ],
    "기타": ["물", '식빵', '부침가루', '튀김가루', '소주', '스파게티면', '당면', '빵가루', '옥수수콘',
           '떡볶이떡', '라면', '단무지', '얼음', '소면', '김가루', '이스트', '떡국떡', '코코아가루',
           '만두', '또띠아', '녹말가루', '피클', '베이킹소다', '다크초콜릿', '사골육수', '딸기잼',
           '커피', '땅콩버터', '떡', '우동면', '칼국수면', '가래떡', '모닝빵', '도토리묵', '라이스페이퍼',
           '초코칩', '유부', '사이다', '국수', '조미김', '탄산수', '바게트', '만두피', '술', '핫케이크가루',
           '콩가루', '표고버섯가루', '에스프레소', '양파즙', '분유', '두유', '면수', '쌈무', '녹차가루',
           '쫄면', '젤라틴', '새우가루', '곤약', '빵', '메밀면', '콜라', '잡채', '쌀국수', '꽁치통조림',
           '맥주', '레몬주스', '김자반', '요구르트', '시리얼', '누룽지', '허브가루', '베이글', '마카로니',
           '물만두', '해물육수', '구운김', '아이스크림', '코코넛밀크', '화이트초콜릿', '미숫가루',
           '바닐라아이스크림', '메밀국수', '오레오', '식용색소', '백앙금', '청포묵', '스프링클', '김밥용 단무지',
           '호떡믹스', '짜장라면', '크래커', '메밀가루', '두부면', '동그랑땡', '초코시럽', '실곤약', '옥수수가루',
           '단호박가루', '코코넛가루', '카스테라', '푸실리', '잼', '초코펜', '치아바타', '막걸리', '불닭볶음면', 
           '럼', '꽃빵', '쑥가루', '물전분', '누텔라', '조랭이떡', '핫도그빵', '잣가루', '말차가루', '인절미',
           '바닐라향', '마시멜로우', '햄버거빵', '홀토마토', '면', '블루베리잼', '납장당면', '넛맥', '한천가루',
           '중면', '마른김', '오렌지주스', '베이크드빈스', '김밥', '도토리가루', '당근라페', '호밀빵', '중화면', 
           '그래놀라', '사과잼', '비빔면', '날콩가루', '파래김', '쫄면사리', '쌍화탕', '통식빵', '떡볶이',
           '쌀국수면', '콩국물', '생면', '낫또', '통밀식빵', '천연가루', '냉면', '깔루아', '국수면', '펜네',
           '배음료', '트러플오일', '춘권피', '단촛물', '장조림', '완두배기', '호밀가루', '멸치볶음', '수제비', 
           '마늘즙', '마시멜로', '후르츠칵테일', ''
            ]
    
}
def determine_category(ingredient):
    for category, items in categories.items():
        if ingredient in items:
            return category
    return "기타"

updated_lines = []
for line in lines:
    ingredient, count = line.strip().split(":")
    category = determine_category(ingredient)
    updated_line = f"{ingredient}|{category}|{count}\n"
    updated_lines.append(updated_line)
    
with open("sorted_ingredients_count_updated.txt", "w", encoding="utf-8") as f:
    f.writelines(updated_lines)
